# %% [markdown]
# # Pandas 설치하기

# %% [markdown]
# `pip install pandas`

# %% [markdown]
# **주의!** `pip freeze > requirements.txt` 로 라이브러리 업데이트 하기

# %% [markdown]
# # 파일 불러오고 저장하기

# %%
import pandas as pd

# %%
df = pd.read_csv('international_football_results.csv')

# %%
df
# Out:
#         game_date         home_team         away_team  home_score  away_score  \
# 0      1872-11-30          Scotland           England           0           0
# 1      1873-03-08           England          Scotland           4           2
# 2      1874-03-07          Scotland           England           2           1
# 3      1875-03-06           England          Scotland           2           2
# 4      1876-03-04          Scotland           England           3           0
# 5      1876-03-25          Scotland             Wales           4           0
# 6      1877-03-03           England          Scotland           1           3
# 7      1877-03-05             Wales          Scotland           0           2
# 8      1878-03-02          Scotland           England           7           2
# 9      1878-03-23          Scotland             Wales           9           0
# 10     1879-01-18           England             Wales           2           1
# ...

# %%
new_df = df.head()
new_df
# Out:
#     game_date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
# new_df.to_csv('sample.csv')

# %% [markdown]
# # 데이터 확인하기

# %%
# df
df.head()
# Out:
#     game_date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df[:10] # df[5:]
# Out:
#     game_date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
# 5  1876-03-25  Scotland     Wales           4           0   Friendly  Glasgow
# 6  1877-03-03   England  Scotland           1           3   Friendly   London
# 7  1877-03-05     Wales  Scotland           0           2   Friendly  Wrexham
# 8  1878-03-02  Scotland   England           7           2   Friendly  Glasgow
# 9  1878-03-23  Scotland     Wales           9           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# ...

# %%
df.iloc[[0, 1, 2, 3], [1]] # index-location based indexing
# Out:
#   home_team
# 0  Scotland
# 1   England
# 2  Scotland
# 3   England

# %%
df.iloc[[0, 1, 2, 3], :]
# Out:
#     game_date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False

# %%
df.loc[[0, 1, 2, 3], ["city"]] # label-location based indexing
# Out:
#       city
# 0  Glasgow
# 1   London
# 2  Glasgow
# 3   London

# %%
df["home_score"][:10]
# Out:
# 0    0
# 1    4
# 2    2
# 3    2
# 4    3
# 5    4
# 6    1
# 7    0
# 8    7
# 9    9
# Name: home_score, dtype: int64

# %%
small_df = df.drop(["city", "neutral"], axis=1)
small_df[:5]
# Out:
#     game_date home_team away_team  home_score  away_score tournament   country
# 0  1872-11-30  Scotland   England           0           0   Friendly  Scotland
# 1  1873-03-08   England  Scotland           4           2   Friendly   England
# 2  1874-03-07  Scotland   England           2           1   Friendly  Scotland
# 3  1875-03-06   England  Scotland           2           2   Friendly   England
# 4  1876-03-04  Scotland   England           3           0   Friendly  Scotland

# %%
small_df["test"] = 1

# %%
small_df[:5]
# Out:
#     game_date home_team away_team  home_score  away_score tournament  \
# 0  1872-11-30  Scotland   England           0           0   Friendly
# 1  1873-03-08   England  Scotland           4           2   Friendly
# 2  1874-03-07  Scotland   England           2           1   Friendly
# 3  1875-03-06   England  Scotland           2           2   Friendly
# 4  1876-03-04  Scotland   England           3           0   Friendly
#
#     country  test
# 0  Scotland     1
# 1   England     1
# 2  Scotland     1
# 3   England     1
# 4  Scotland     1

# %%
df[df["home_team"] == "Scotland"][:10]
# Out:
#      game_date home_team away_team  home_score  away_score tournament  \
# 0   1872-11-30  Scotland   England           0           0   Friendly
# 2   1874-03-07  Scotland   England           2           1   Friendly
# 4   1876-03-04  Scotland   England           3           0   Friendly
# 5   1876-03-25  Scotland     Wales           4           0   Friendly
# 8   1878-03-02  Scotland   England           7           2   Friendly
# 9   1878-03-23  Scotland     Wales           9           0   Friendly
# 13  1880-03-13  Scotland   England           5           4   Friendly
# 15  1880-03-27  Scotland     Wales           5           1   Friendly
# 21  1882-03-11  Scotland   England           5           1   Friendly
# 23  1882-03-25  Scotland     Wales           5           0   Friendly
#
#        city   country  neutral
# 0   Glasgow  Scotland    False
# 2   Glasgow  Scotland    False
# 4   Glasgow  Scotland    False
# 5   Glasgow  Scotland    False
# 8   Glasgow  Scotland    False
# ...

# %%
df[df["home_score"] > 5].head()
# Out:
#      game_date home_team         away_team  home_score  away_score  \
# 8   1878-03-02  Scotland           England           7           2
# 9   1878-03-23  Scotland             Wales           9           0
# 20  1882-02-25     Wales  Northern Ireland           7           1
# 25  1883-02-24   England  Northern Ireland           7           0
# 30  1884-02-09     Wales  Northern Ireland           6           0
#
#               tournament       city   country  neutral
# 8               Friendly    Glasgow  Scotland    False
# 9               Friendly    Glasgow  Scotland    False
# 20              Friendly    Wrexham     Wales    False
# 25              Friendly  Liverpool   England    False
# 30  British Championship    Wrexham     Wales    False

# %%
df[df["home_score"] > df["away_score"]].head()
# Out:
#     game_date home_team away_team  home_score  away_score tournament     city  \
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
# 5  1876-03-25  Scotland     Wales           4           0   Friendly  Glasgow
# 8  1878-03-02  Scotland   England           7           2   Friendly  Glasgow
#
#     country  neutral
# 1   England    False
# 2  Scotland    False
# 4  Scotland    False
# 5  Scotland    False
# 8  Scotland    False

# %% [markdown]
# # 데이터에서 인사이트 얻기

# %%
df.head()
# Out:
#     game_date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.count()
# Out:
# game_date     39669
# home_team     39669
# away_team     39669
# home_score    39669
# away_score    39669
# tournament    39669
# city          39669
# country       39669
# neutral       39669
# dtype: int64

# %%
df[df["home_score"] > df["away_score"]].count()
# Out:
# game_date     19301
# home_team     19301
# away_team     19301
# home_score    19301
# away_score    19301
# tournament    19301
# city          19301
# country       19301
# neutral       19301
# dtype: int64

# %%
grouped = df.groupby("home_team")

# %%
grouped

# %%
grouped.groups
# Out:
# {'Abkhazia': Int64Index([35841, 35872, 35901, 37721, 37741, 37760, 37813, 37838, 38611,
#              39483, 39516, 39533, 39554, 39575],
#             dtype='int64'),
#  'Afghanistan': Int64Index([ 2314,  9697,  9699, 10125, 25122, 25127, 25991, 28072, 29564,
#              30133, 30329, 30333, 31681, 32693, 32958, 33615, 34782, 35225,
#              35236, 35249, 35720, 35728, 35754, 35762, 36760, 37086, 37296,
#              37442, 37449, 37451, 37617, 38458, 38524, 38614, 39078, 39382],
#             dtype='int64'),
#  'Albania': Int64Index([ 2568,  2579,  2581,  2583,  2632,  2670,  2778,  3002,  3037,
#               3053,
#              ...
#              37987, 38052, 38162, 38276, 38525, 38917, 39068, 39375, 39462,
#              39522],
#             dtype='int64', length=166),
#  'Alderney': Int64Index([25581, 32938, 32953, 32967, 36927, 38763], dtype='int64'),
#  'Algeria': Int64Index([ 5232,  5371,  5492,  5648,  5821,  5939,  6266,  6390,  6403,
#               6643,
# ...

# %%
grouped.get_group('Albania')[:20] # df[df["home_team"] == "Albania"]
# Out:
#        game_date home_team         away_team  home_score  away_score  \
# 2568  1946-08-22   Albania        Montenegro           5           0
# 2579  1946-10-07   Albania        Yugoslavia           2           3
# 2581  1946-10-09   Albania          Bulgaria           3           1
# 2583  1946-10-13   Albania           Romania           1           0
# 2632  1947-05-25   Albania           Romania           0           4
# 2670  1947-09-14   Albania        Yugoslavia           2           4
# 2778  1948-05-23   Albania           Hungary           0           0
# 3002  1949-11-29   Albania           Romania           1           4
# 3037  1950-05-01   Albania            Poland           0           0
# 3053  1950-06-04   Albania          Bulgaria           2           1
# 3349  1952-11-29   Albania    Czechoslovakia           3           2
# 3520  1953-11-29   Albania            Poland           2           0
# 4266  1958-05-04   Albania         German DR           1           1
# ...

# %%
import numpy as np

# %%
grouped["home_score"].agg(np.mean)[:10]
# Out:
# home_team
# Abkhazia               2.214286
# Afghanistan            1.361111
# Albania                1.114458
# Alderney               0.500000
# Algeria                1.775801
# American Samoa         0.750000
# Andorra                0.324324
# Angola                 1.422360
# Anguilla               0.687500
# Antigua and Barbuda    1.557692
# Name: home_score, dtype: float64

# %%
df.sort_values(by="home_score", ascending=False)[:10]
# Out:
#         game_date  home_team       away_team  home_score  away_score  \
# 23680  2001-04-11  Australia  American Samoa          31           0
# 10860  1979-08-30       Fiji        Kiribati          24           0
# 23677  2001-04-09  Australia           Tonga          22           0
# 28691  2006-11-24      Sápmi          Monaco          21           1
# 22455  2000-02-14     Kuwait          Bhutan          20           0
# 23342  2000-11-24       Iran            Guam          19           0
# 25550  2003-06-29  Gibraltar            Sark          19           0
# 22368  2000-01-26      China            Guam          19           0
# 10863  1979-08-30     Tahiti          Tuvalu          18           0
# 25554  2003-06-30     Tahiti   Micronesia FS          17           0
#
#                          tournament           city    country  neutral
# 23680  FIFA World Cup qualification  Coffs Harbour  Australia    False
# ...

# %%
df.sort_values(by=["home_team" ,"home_score"], ascending=[True, False])[:10]
# Out:
#         game_date home_team                away_team  home_score  away_score  \
# 37721  2016-05-29  Abkhazia           Chagos Islands           9           0
# 39554  2018-06-05  Abkhazia              Tamil Eelam           6           0
# 39483  2018-05-31  Abkhazia                    Tibet           3           0
# 37760  2016-06-01  Abkhazia                    Sápmi           2           0
# 37813  2016-06-04  Abkhazia          Northern Cyprus           2           0
# 38611  2017-06-05  Abkhazia            South Ossetia           2           1
# 39533  2018-06-03  Abkhazia          Northern Cyprus           2           2
# 39575  2018-06-07  Abkhazia  United Koreans in Japan           2           0
# 35841  2014-06-01  Abkhazia                Occitania           1           1
# 37741  2016-05-31  Abkhazia          Western Armenia           1           0
#
#                          tournament       city          country  neutral
# ...

# %%
df.head()
# Out:
#     game_date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.describe()
# Out:
#          home_score    away_score
# count  39669.000000  39669.000000
# mean       1.747763      1.187880
# std        1.746964      1.399707
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
df.loc[:5, ["home_score", "away_score"]]
# Out:
#    home_score  away_score
# 0           0           0
# 1           4           2
# 2           2           1
# 3           2           2
# 4           3           0
# 5           4           0

# %%
df.loc[:5, ["home_score", "away_score"]].cumsum()
# Out:
#    home_score  away_score
# 0           0           0
# 1           4           2
# 2           6           3
# 3           8           5
# 4          11           5
# 5          15           5

# %%
pd.unique(df["home_team"])
# Out:
# array(['Scotland', 'England', 'Wales', 'Northern Ireland', 'USA',
#        'Uruguay', 'Austria', 'Hungary', 'Argentina', 'Belgium', 'France',
#        'Netherlands', 'Czechoslovakia', 'Switzerland', 'Sweden',
#        'Germany', 'Italy', 'Chile', 'Norway', 'Finland', 'Luxembourg',
#        'Russia', 'Denmark', 'Brazil', 'Japan', 'Paraguay', 'Canada',
#        'Estonia', 'Costa Rica', 'Guatemala', 'Spain', 'Poland',
#        'Yugoslavia', 'New Zealand', 'Romania', 'Latvia', 'Portugal',
#        'China', 'Australia', 'Lithuania', 'Turkey', 'Mexico', 'Aruba',
#        'Egypt', 'Haiti', 'Philippines', 'Bulgaria', 'Jamaica', 'Kenya',
#        'Bolivia', 'Peru', 'Honduras', 'Guyana', 'Uganda', 'Belarus',
#        'El Salvador', 'Barbados', 'Ireland', 'Trinidad and Tobago',
#        'Greece', 'Curaçao', 'Dominica', 'Guadeloupe', 'Israel',
#        'Suriname', 'French Guyana', 'Cuba', 'Colombia', 'Ecuador',
#        'St. Kitts and Nevis', 'Panama', 'Slovakia', 'Manchukuo',
# ...

# %%
df["home_team"].value_counts()
# Out:
# Brazil                       552
# Argentina                    535
# Germany                      495
# Mexico                       494
# England                      483
# Sweden                       478
# France                       471
# Korea Republic               449
# Hungary                      445
# Italy                        434
# Austria                      411
# Netherlands                  409
# Belgium                      402
# USA                          400
# Switzerland                  396
# Denmark                      395
# Norway                       389
# Chile                        385
# Poland                       375
# Scotland                     369
# Egypt                        368
# Kenya                        360
# Japan                        356
# Saudi Arabia                 351
# Spain                        351
# Uruguay                      339
# Malawi                       327
# China                        326
# ...

# %%
df.count()
# Out:
# game_date     39669
# home_team     39669
# away_team     39669
# home_score    39669
# away_score    39669
# tournament    39669
# city          39669
# country       39669
# neutral       39669
# dtype: int64

# %%
df.size
# Out:
# 357021
